# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Dropbox (Trilations)\3L - 0681 - Janssen LATAM Loyalty M1 2021\13. Modeling\4. MAF models\Model Combinations LATAM 2021M1 - MAF -Samira.xlsx", sheet_name='models')

# %%
df.head()
# Out:
#    model_nr  line_nr country_region_name  \
# 0         1        1               LATAM
# 1         1        2               LATAM
# 2         2        1               LATAM
# 3         2        2               LATAM
# 4         3        1               LATAM
#
#                                            d1ccode country_region_code  \
# 0  rgARG, rgBRA, rgCEN, rgCHL, rgCOL, rgMEX, rgPER              rgCLAT
# 1  rgARG, rgBRA, rgCEN, rgCHL, rgCOL, rgMEX, rgPER              rgCLAT
# 2  rgARG, rgBRA, rgCEN, rgCHL, rgCOL, rgMEX, rgPER              rgCLAT
# 3  rgARG, rgBRA, rgCEN, rgCHL, rgCOL, rgMEX, rgPER              rgCLAT
# 4         rgARG, rgBRA, rgCEN, rgCHL, rgCOL, rgPER              rgCLAT
#
#   ta_name d1treatmentarea own_company_name own_company_code own_brand_name  \
# 0      MM             ta1          Janssen             co10       Darzalex
# 1      MM             ta1          Janssen             co10       Darzalex
# ...
